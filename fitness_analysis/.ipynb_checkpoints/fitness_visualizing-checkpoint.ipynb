# %% [markdown]
# ### 휴일 추가 부분(base)

# %%
import pandas as pd
import holidays

# %%
kr_holidays = holidays.KR()

df = pd.read_csv('./data/2020_통합_v2.0_my idea.csv')
df['휴일'] = df.Date.apply(lambda x: 'holiday' if x in kr_holidays else 'non-holiday')
df.head()

# %%
df.to_csv('./data/2020_통합_v2.0_my idea.csv',encoding='cp949',index=False)

# %% [markdown]
# ### page 9 데이터 삭제

# %%
df = pd.read_csv('./data/2020_통합_v2.0_my idea.csv',encoding='cp949')

# %%
ls = set()

for dt, cnt in df.groupby('Date')['No'].count().items():
    if cnt<=5:
        ls.add(dt)

# %%
mask = df['Date'].isin(ls)
df = df[~mask]

df.to_csv('./data/2020_통합_v2.1_my idea.csv',encoding='cp949',index=False)

# %% [markdown]
# ### page 13 데이터 삭제

# %%
df = pd.read_csv('./data/2020_통합_v2.1_my idea.csv',encoding='cp949')

# %%
df = df[df['Gender2']!='공용']
df.to_csv('./data/2020_통합_v2.2_my idea.csv',encoding='cp949',index=False)

# %%
df
# Out:
#             No Area  MonthlySeq Area.Month.Seq        Date   Time Gender  \
# 0            1    A           1             A1  2020-01-01   8:13     여자
# 1            2    A           2             A2  2020-01-01   8:18     여자
# 2            3    A           3             A3  2020-01-01   8:37     남자
# 3            4    A           4             A4  2020-01-01   8:43     남자
# 4            5    A           5             A5  2020-01-01   8:46     남자
# ...        ...  ...         ...            ...         ...    ...    ...
# 291285  291325    E        3388          E3388  2020-11-23  12:51     여자
# 291286  291326    E        3389          E3389  2020-11-23  12:52     남자
# 291287  291327    E        3390          E3390  2020-11-23  12:54     남자
# 291288  291328    E        3391          E3391  2020-11-23  13:04     여자
# 291289  291329    E        3392          E3392  2020-11-23  13:22     여자
#
#        Gender2  Age  Age2 Remark  Year  Month  Day  Hour   요일           휴일
# 0           여자    0   NaN     출입  2020      1    1     8  수요일      holiday
# 1           여자   69  69.0     출입  2020      1    1     8  수요일      holiday
# 2           남자   36  36.0     출입  2020      1    1     8  수요일      holiday
# 3           남자   42  42.0     출입  2020      1    1     8  수요일      holiday
# 4           남자   40  40.0     출입  2020      1    1     8  수요일      holiday
# ...        ...  ...   ...    ...   ...    ...  ...   ...  ...          ...
# 291285      여자   25  25.0     출입  2020     11   23    12  월요일  non-holiday
# 291286      남자   20  20.0     출입  2020     11   23    12  월요일  non-holiday
# 291287      남자   50  50.0     출입  2020     11   23    12  월요일  non-holiday
# 291288      여자   44  44.0     출입  2020     11   23    13  월요일  non-holiday
# 291289      여자    0   NaN     출입  2020     11   23    13  월요일  non-holiday
#
# [291284 rows x 17 columns]

# %% [markdown]
# ### page 14 NULL 처리

# %%
df = pd.read_csv('./data/2020_통합_v2.2_my idea.csv',encoding='cp949')

# %%
df['Age2'] = df.apply(lambda x : None if x['Age']<=5 else x['Age2'],axis=1)
df.to_csv('./data/2020_통합_v2.3_my idea.csv',encoding='cp949',index=False)

# %%
df
# Out:
#             No Area  MonthlySeq Area.Month.Seq        Date   Time Gender  \
# 0            1    A           1             A1  2020-01-01   8:13     여자
# 1            2    A           2             A2  2020-01-01   8:18     여자
# 2            3    A           3             A3  2020-01-01   8:37     남자
# 3            4    A           4             A4  2020-01-01   8:43     남자
# 4            5    A           5             A5  2020-01-01   8:46     남자
# ...        ...  ...         ...            ...         ...    ...    ...
# 291279  291325    E        3388          E3388  2020-11-23  12:51     여자
# 291280  291326    E        3389          E3389  2020-11-23  12:52     남자
# 291281  291327    E        3390          E3390  2020-11-23  12:54     남자
# 291282  291328    E        3391          E3391  2020-11-23  13:04     여자
# 291283  291329    E        3392          E3392  2020-11-23  13:22     여자
#
#        Gender2  Age  Age2 Remark  Year  Month  Day  Hour   요일           휴일
# 0           여자    0   NaN     출입  2020      1    1     8  수요일      holiday
# 1           여자   69  69.0     출입  2020      1    1     8  수요일      holiday
# 2           남자   36  36.0     출입  2020      1    1     8  수요일      holiday
# 3           남자   42  42.0     출입  2020      1    1     8  수요일      holiday
# 4           남자   40  40.0     출입  2020      1    1     8  수요일      holiday
# ...        ...  ...   ...    ...   ...    ...  ...   ...  ...          ...
# 291279      여자   25  25.0     출입  2020     11   23    12  월요일  non-holiday
# 291280      남자   20  20.0     출입  2020     11   23    12  월요일  non-holiday
# 291281      남자   50  50.0     출입  2020     11   23    12  월요일  non-holiday
# 291282      여자   44  44.0     출입  2020     11   23    13  월요일  non-holiday
# 291283      여자    0   NaN     출입  2020     11   23    13  월요일  non-holiday
#
# [291284 rows x 17 columns]

# %% [markdown]
# ### page16 시각화

# %%
df = pd.read_csv('./data/2020_통합_v2.3_my idea.csv',encoding='cp949')

# %%
temp_df = pd.DataFrame(df.groupby('Area')['No'].count()).rename(columns={'No':'빈도'})

# %%
import numpy as np
temp_df['퍼센트'] = np.round(temp_df['빈도']/temp_df['빈도'].sum()*100,1)

# %%
temp_df['누적퍼센트'] = np.cumsum(temp_df['퍼센트'])

# %%
temp_df.loc['합계'] = np.sum(temp_df)[:-1]

# %%
temp_df
# Out:
#             빈도   퍼센트  누적퍼센트
# Area
# A      46446.0  15.9   15.9
# B      35935.0  12.3   28.2
# C      63042.0  21.6   49.8
# D      33138.0  11.4   61.2
# E      18197.0   6.2   67.4
# F      44616.0  15.3   82.7
# G      44283.0  15.2   97.9
# T       5627.0   1.9   99.8
# 합계    291284.0  99.8    NaN

# %% [markdown]
# ### page 18 시각화

# %%
temp_df = pd.DataFrame(df.groupby('Month')['No'].count()).rename(columns={'No':'빈도'})
temp_df['퍼센트'] = np.round(temp_df['빈도']/temp_df['빈도'].sum()*100,1)
temp_df['누적퍼센트'] = np.cumsum(temp_df['퍼센트'])
temp_df.loc['합계'] = np.sum(temp_df)[:-1]
temp_df
# Out:
#              빈도   퍼센트  누적퍼센트
# Month
# 1       23686.0   8.1    8.1
# 2       21494.0   7.4   15.5
# 3       15252.0   5.2   20.7
# 4       17115.0   5.9   26.6
# 5       22526.0   7.7   34.3
# 6       30180.0  10.4   44.7
# 7       43346.0  14.9   59.6
# 8       39453.0  13.5   73.1
# 9       15686.0   5.4   78.5
# 10      34168.0  11.7   90.2
# 11      28378.0   9.7   99.9
# 합계     291284.0  99.9    NaN

# %% [markdown]
# ### page 20 시각화

# %%
temp_df = df.groupby(['Month','Area'])['No'].count().unstack()

# %%
temp_df.loc['전체'] = temp_df.loc[1:12].sum().to_list()

# %%
temp_df['전체'] = [temp_df.iloc[i].sum() for i in range(0,12)]

# %%
temp_df
# Out:
# Area         A        B        C        D        E        F        G       T  \
# Month
# 1       4272.0   2262.0   6350.0   3608.0      NaN   3604.0   3590.0     NaN
# 2       4004.0   1598.0   5777.0   3378.0      NaN   3372.0   3365.0     NaN
# 3       3406.0   1264.0   3558.0   2352.0      NaN   2336.0   2336.0     NaN
# 4       3502.0   2133.0   4243.0   2417.0      NaN   2414.0   2406.0     NaN
# 5       4595.0   3488.0   5643.0   3129.0      NaN   2547.0   3121.0     3.0
# 6       5278.0   4438.0   6967.0   3838.0   1763.0   3837.0   3831.0   228.0
# 7       5774.0   5916.0   8722.0   4060.0   3936.0   6602.0   6609.0  1727.0
# 8       4689.0   4592.0   6867.0   3270.0   3575.0   7843.0   7851.0   766.0
# 9       2407.0   2435.0   3346.0   1534.0   1803.0   2434.0   1529.0   198.0
# 10      4713.0   4545.0   6728.0   3118.0   3728.0   4913.0   4922.0  1501.0
# 11      3806.0   3264.0   4841.0   2434.0   3392.0   4714.0   4723.0  1204.0
# 전체     46446.0  35935.0  63042.0  33138.0  18197.0  44616.0  44283.0  5627.0
#
# Area         전체
# Month
# 1       23686.0
# 2       21494.0
# 3       15252.0
# 4       17115.0
# 5       22526.0
# 6       30180.0
# 7       43346.0
# 8       39453.0
# 9       15686.0
# 10      34168.0
# 11      28378.0
# 전체     291284.0

# %% [markdown]
# ### page 24 시각화

# %%
for i in temp_df.index.values:
    temp_df.loc[str(i)+'%'] = np.round(temp_df.loc[i]/temp_df.loc['전체']*100,1)

# %%
ls = []

for ind, i in enumerate(temp_df.index[:12]):
    ls.append(i)
    ls.append(temp_df.index[ind+12])

# %%
temp_df.reindex(index=ls)
# Out:
# Area         A        B        C        D        E        F        G       T  \
# Month
# 1       4272.0   2262.0   6350.0   3608.0      NaN   3604.0   3590.0     NaN
# 1%         9.2      6.3     10.1     10.9      NaN      8.1      8.1     NaN
# 2       4004.0   1598.0   5777.0   3378.0      NaN   3372.0   3365.0     NaN
# 2%         8.6      4.4      9.2     10.2      NaN      7.6      7.6     NaN
# 3       3406.0   1264.0   3558.0   2352.0      NaN   2336.0   2336.0     NaN
# 3%         7.3      3.5      5.6      7.1      NaN      5.2      5.3     NaN
# 4       3502.0   2133.0   4243.0   2417.0      NaN   2414.0   2406.0     NaN
# 4%         7.5      5.9      6.7      7.3      NaN      5.4      5.4     NaN
# 5       4595.0   3488.0   5643.0   3129.0      NaN   2547.0   3121.0     3.0
# 5%         9.9      9.7      9.0      9.4      NaN      5.7      7.0     0.1
# 6       5278.0   4438.0   6967.0   3838.0   1763.0   3837.0   3831.0   228.0
# 6%        11.4     12.4     11.1     11.6      9.7      8.6      8.7     4.1
# 7       5774.0   5916.0   8722.0   4060.0   3936.0   6602.0   6609.0  1727.0
# 7%        12.4     16.5     13.8     12.3     21.6     14.8     14.9    30.7
# 8       4689.0   4592.0   6867.0   3270.0   3575.0   7843.0   7851.0   766.0
# 8%        10.1     12.8     10.9      9.9     19.6     17.6     17.7    13.6
# 9       2407.0   2435.0   3346.0   1534.0   1803.0   2434.0   1529.0   198.0
# 9%         5.2      6.8      5.3      4.6      9.9      5.5      3.5     3.5
# 10      4713.0   4545.0   6728.0   3118.0   3728.0   4913.0   4922.0  1501.0
# 10%       10.1     12.6     10.7      9.4     20.5     11.0     11.1    26.7
# 11      3806.0   3264.0   4841.0   2434.0   3392.0   4714.0   4723.0  1204.0
# 11%        8.2      9.1      7.7      7.3     18.6     10.6     10.7    21.4
# 전체     46446.0  35935.0  63042.0  33138.0  18197.0  44616.0  44283.0  5627.0
# 전체%      100.0    100.0    100.0    100.0    100.0    100.0    100.0   100.0
#
# Area         전체
# Month
# 1       23686.0
# 1%          8.1
# 2       21494.0
# 2%          7.4
# 3       15252.0
# 3%          5.2
# 4       17115.0
# 4%          5.9
# 5       22526.0
# 5%          7.7
# 6       30180.0
# 6%         10.4
# 7       43346.0
# 7%         14.9
# 8       39453.0
# 8%         13.5
# 9       15686.0
# 9%          5.4
# 10      34168.0
# 10%        11.7
# 11      28378.0
# 11%         9.7
# 전체     291284.0
# 전체%       100.0

# %% [markdown]
# ### page 26 시각화

# %%
df = pd.read_csv('./data/2020_통합_v2.3_my idea.csv',encoding='cp949')

# %%
temp_df = df.groupby(['Gender2','Month'])['No'].count().unstack()

# %%
temp_df.loc['전체'] = temp_df.iloc[:2].sum().to_list()
temp_df['전체'] = [temp_df.iloc[i].sum() for i in range(0,3)]

# %%
import numpy

for i in temp_df.index.values:
    temp_df.loc[str(i)+'Gender2 중 %'] = np.round(temp_df.loc[i]/temp_df.loc[i]['전체']*100,1)
    
for i in temp_df.index[:3].values:
    temp_df.loc[str(i)+'Month 중 %'] = np.round(temp_df.loc[i]/temp_df.loc['전체']*100,1)
    
for i in temp_df.index[:3].values:
    temp_df.loc[str(i)+'전체 %'] = np.round(temp_df.loc[i]/temp_df.loc['전체']['전체']*100,1)

# %%
ls = []

for ind, i in enumerate(temp_df.index[:3]):
    ls.append(i)
    ls.append(temp_df.index[ind+3])
    ls.append(temp_df.index[ind+6])
    ls.append(temp_df.index[ind+9])

# %%
temp_df.reindex(index=ls)
# Out:
# Month                1        2        3        4        5        6        7  \
# Gender2
# 남자             12626.0  12086.0   9542.0  10253.0  12584.0  16572.0  22447.0
# 남자Gender2 중 %      7.9      7.5      6.0      6.4      7.9     10.3     14.0
# 남자Month 중 %       53.3     56.2     62.6     59.9     55.9     54.9     51.8
# 남자전체 %             4.3      4.1      3.3      3.5      4.3      5.7      7.7
# 여자             11060.0   9408.0   5710.0   6862.0   9942.0  13608.0  20899.0
# 여자Gender2 중 %      8.4      7.2      4.4      5.2      7.6     10.4     15.9
# 여자Month 중 %       46.7     43.8     37.4     40.1     44.1     45.1     48.2
# 여자전체 %             3.8      3.2      2.0      2.4      3.4      4.7      7.2
# 전체             23686.0  21494.0  15252.0  17115.0  22526.0  30180.0  43346.0
# 전체Gender2 중 %      8.1      7.4      5.2      5.9      7.7     10.4     14.9
# 전체Month 중 %      100.0    100.0    100.0    100.0    100.0    100.0    100.0
# 전체전체 %             8.1      7.4      5.2      5.9      7.7     10.4     14.9
#
# Month                8        9       10       11        전체
# Gender2
# 남자             22015.0   8530.0  18071.0  15460.0  160186.0
# 남자Gender2 중 %     13.7      5.3     11.3      9.7     100.0
# 남자Month 중 %       55.8     54.4     52.9     54.5      55.0
# 남자전체 %             7.6      2.9      6.2      5.3      55.0
# 여자             17438.0   7156.0  16097.0  12918.0  131098.0
# 여자Gender2 중 %     13.3      5.5     12.3      9.9     100.0
# 여자Month 중 %       44.2     45.6     47.1     45.5      45.0
# 여자전체 %             6.0      2.5      5.5      4.4      45.0
# 전체             39453.0  15686.0  34168.0  28378.0  291284.0
# 전체Gender2 중 %     13.5      5.4     11.7      9.7     100.0
# 전체Month 중 %      100.0    100.0    100.0    100.0     100.0
# 전체전체 %            13.5      5.4     11.7      9.7     100.0

# %% [markdown]
# ### page 27 시각화

# %%
df = pd.read_csv('./data/2020_통합_v2.3_my idea.csv',encoding='cp949')

# %%
temp_df = pd.DataFrame(df.groupby('Hour')['No'].count()).rename(columns={'No':'빈도'})
temp_df['퍼센트'] = np.round(temp_df['빈도']/temp_df['빈도'].sum()*100,1)
temp_df['누적퍼센트'] = np.cumsum(temp_df['퍼센트'])
temp_df.loc['합계'] = np.sum(temp_df)[:-1]

# %%
temp_df
# Out:
#             빈도   퍼센트  누적퍼센트
# Hour
# 0         34.0   0.0    0.0
# 5       1624.0   0.6    0.6
# 6      10844.0   3.7    4.3
# 7      12958.0   4.4    8.7
# 8      12626.0   4.3   13.0
# 9      14565.0   5.0   18.0
# 10     15759.0   5.4   23.4
# 11     16279.0   5.6   29.0
# 12     14343.0   4.9   33.9
# 13     10836.0   3.7   37.6
# 14     12887.0   4.4   42.0
# 15     14683.0   5.0   47.0
# 16     15680.0   5.4   52.4
# 17     18491.0   6.3   58.7
# 18     27489.0   9.4   68.1
# 19     28644.0   9.8   77.9
# 20     27528.0   9.5   87.4
# 21     21072.0   7.2   94.6
# 22     13236.0   4.5   99.1
# 23      1706.0   0.6   99.7
# 합계    291284.0  99.7    NaN

# %% [markdown]
# ### page 29 시각화

# %%
df = pd.read_csv('./data/2020_통합_v2.3_my idea.csv',encoding='cp949')

# %%
temp_df = df.groupby(['요일','Hour'])['No'].count().unstack()

# %%
temp_df.loc['전체'] = temp_df.iloc[:7].sum().to_list()
temp_df['전체'] = [temp_df.iloc[i].sum() for i in range(0,7)]

# %%
temp_df
# Out:
# Hour     0       5        6        7        8        9       10       11  \
# 요일
# 금요일    6.0   292.0   1867.0   2293.0   2130.0   2540.0   2695.0   2717.0
# 목요일    6.0   329.0   2059.0   2492.0   2052.0   2461.0   2770.0   2808.0
# 수요일   12.0   330.0   2205.0   2456.0   2175.0   2454.0   2775.0   2701.0
# 월요일    NaN   335.0   2321.0   2613.0   2144.0   2661.0   2774.0   2925.0
# 토요일    1.0     NaN      4.0    390.0   1928.0   1853.0   1994.0   2160.0
# 화요일    9.0   338.0   2388.0   2714.0   2197.0   2596.0   2751.0   2968.0
# 전체    34.0  1624.0  10844.0  12958.0  12626.0  14565.0  15759.0  16279.0
#
# Hour       12       13  ...       15       16       17       18       19  \
# 요일                      ...
# 금요일    2293.0   1632.0  ...   2430.0   2705.0   3130.0   4248.0   4186.0
# 목요일    2494.0   1631.0  ...   2304.0   2474.0   3052.0   4875.0   5102.0
# 수요일    2548.0   1867.0  ...   2450.0   2631.0   3318.0   5318.0   5415.0
# 월요일    2595.0   1867.0  ...   2532.0   2817.0   3461.0   5538.0   5972.0
# 토요일    1847.0   2065.0  ...   2401.0   2293.0   2098.0   1912.0   2042.0
# 화요일    2566.0   1774.0  ...   2566.0   2760.0   3432.0   5598.0   5927.0
# 전체    14343.0  10836.0  ...  14683.0  15680.0  18491.0  27489.0  28644.0
#
# Hour       20       21       22      23        전체
# 요일
# 금요일    4115.0   3320.0   2280.0   304.0   47408.0
# 목요일    4870.0   4083.0   2641.0   295.0   50716.0
# 수요일    5068.0   4192.0   2553.0   341.0   52992.0
# 월요일    5507.0   4378.0   2722.0   345.0   55674.0
# 토요일    2329.0    494.0     22.0     1.0   28034.0
# 화요일    5639.0   4605.0   3018.0   420.0   56460.0
# 전체    27528.0  21072.0  13236.0  1706.0  291284.0
#
# [7 rows x 21 columns]

# %%
import numpy

for i in temp_df.index.values:
    temp_df.loc[str(i)+' 중 %'] = np.round(temp_df.loc[i]/temp_df.loc[i]['전체']*100,1)
    
for i in temp_df.index[:7].values:
    temp_df.loc[str(i)+'Hour 중 %'] = np.round(temp_df.loc[i]/temp_df.loc['전체']*100,1)
    
for i in temp_df.index[:7].values:
    temp_df.loc[str(i)+'전체 %'] = np.round(temp_df.loc[i]/temp_df.loc['전체']['전체']*100,1)

# %%
# # row 생략 없이 출력
# pd.set_option('display.max_rows', None)
# # col 생략 없이 출력
# pd.set_option('display.max_columns', None)

# %%
ls = []

for ind, i in enumerate(temp_df.index[:7]):
    ls.append(i)
    ls.append(temp_df.index[ind+7])
    ls.append(temp_df.index[ind+14])
    ls.append(temp_df.index[ind+21])

# %%
temp_df.reindex(index=ls)
# Out:
# Hour             0       5        6        7        8        9       10  \
# 요일
# 금요일            6.0   292.0   1867.0   2293.0   2130.0   2540.0   2695.0
# 금요일 중 %        0.0     0.6      3.9      4.8      4.5      5.4      5.7
# 금요일Hour 중 %   17.6    18.0     17.2     17.7     16.9     17.4     17.1
# 금요일전체 %        0.0     0.1      0.6      0.8      0.7      0.9      0.9
# 목요일            6.0   329.0   2059.0   2492.0   2052.0   2461.0   2770.0
# 목요일 중 %        0.0     0.6      4.1      4.9      4.0      4.9      5.5
# 목요일Hour 중 %   17.6    20.3     19.0     19.2     16.3     16.9     17.6
# 목요일전체 %        0.0     0.1      0.7      0.9      0.7      0.8      1.0
# 수요일           12.0   330.0   2205.0   2456.0   2175.0   2454.0   2775.0
# 수요일 중 %        0.0     0.6      4.2      4.6      4.1      4.6      5.2
# 수요일Hour 중 %   35.3    20.3     20.3     19.0     17.2     16.8     17.6
# 수요일전체 %        0.0     0.1      0.8      0.8      0.7      0.8      1.0
# 월요일            NaN   335.0   2321.0   2613.0   2144.0   2661.0   2774.0
# 월요일 중 %        NaN     0.6      4.2      4.7      3.9      4.8      5.0
# 월요일Hour 중 %    NaN    20.6     21.4     20.2     17.0     18.3     17.6
# 월요일전체 %        NaN     0.1      0.8      0.9      0.7      0.9      1.0
# 토요일            1.0     NaN      4.0    390.0   1928.0   1853.0   1994.0
# 토요일 중 %        0.0     NaN      0.0      1.4      6.9      6.6      7.1
# 토요일Hour 중 %    2.9     NaN      0.0      3.0     15.3     12.7     12.7
# 토요일전체 %        0.0     NaN      0.0      0.1      0.7      0.6      0.7
# 화요일            9.0   338.0   2388.0   2714.0   2197.0   2596.0   2751.0
# 화요일 중 %        0.0     0.6      4.2      4.8      3.9      4.6      4.9
# 화요일Hour 중 %   26.5    20.8     22.0     20.9     17.4     17.8     17.5
# 화요일전체 %        0.0     0.1      0.8      0.9      0.8      0.9      0.9
# 전체            34.0  1624.0  10844.0  12958.0  12626.0  14565.0  15759.0
# 전체 중 %         0.0     0.6      3.7      4.4      4.3      5.0      5.4
# 전체Hour 중 %   100.0   100.0    100.0    100.0    100.0    100.0    100.0
# 전체전체 %         0.0     0.6      3.7      4.4      4.3      5.0      5.4
#
# Hour              11       12       13  ...       15       16       17  \
# 요일                                      ...
# 금요일           2717.0   2293.0   1632.0  ...   2430.0   2705.0   3130.0
# 금요일 중 %          5.7      4.8      3.4  ...      5.1      5.7      6.6
# 금요일Hour 중 %     16.7     16.0     15.1  ...     16.5     17.3     16.9
# 금요일전체 %          0.9      0.8      0.6  ...      0.8      0.9      1.1
# 목요일           2808.0   2494.0   1631.0  ...   2304.0   2474.0   3052.0
# 목요일 중 %          5.5      4.9      3.2  ...      4.5      4.9      6.0
# 목요일Hour 중 %     17.2     17.4     15.1  ...     15.7     15.8     16.5
# 목요일전체 %          1.0      0.9      0.6  ...      0.8      0.8      1.0
# 수요일           2701.0   2548.0   1867.0  ...   2450.0   2631.0   3318.0
# 수요일 중 %          5.1      4.8      3.5  ...      4.6      5.0      6.3
# 수요일Hour 중 %     16.6     17.8     17.2  ...     16.7     16.8     17.9
# 수요일전체 %          0.9      0.9      0.6  ...      0.8      0.9      1.1
# 월요일           2925.0   2595.0   1867.0  ...   2532.0   2817.0   3461.0
# 월요일 중 %          5.3      4.7      3.4  ...      4.5      5.1      6.2
# 월요일Hour 중 %     18.0     18.1     17.2  ...     17.2     18.0     18.7
# 월요일전체 %          1.0      0.9      0.6  ...      0.9      1.0      1.2
# 토요일           2160.0   1847.0   2065.0  ...   2401.0   2293.0   2098.0
# 토요일 중 %          7.7      6.6      7.4  ...      8.6      8.2      7.5
# 토요일Hour 중 %     13.3     12.9     19.1  ...     16.4     14.6     11.3
# 토요일전체 %          0.7      0.6      0.7  ...      0.8      0.8      0.7
# 화요일           2968.0   2566.0   1774.0  ...   2566.0   2760.0   3432.0
# 화요일 중 %          5.3      4.5      3.1  ...      4.5      4.9      6.1
# 화요일Hour 중 %     18.2     17.9     16.4  ...     17.5     17.6     18.6
# 화요일전체 %          1.0      0.9      0.6  ...      0.9      0.9      1.2
# 전체           16279.0  14343.0  10836.0  ...  14683.0  15680.0  18491.0
# 전체 중 %           5.6      4.9      3.7  ...      5.0      5.4      6.3
# 전체Hour 중 %     100.0    100.0    100.0  ...    100.0    100.0    100.0
# 전체전체 %           5.6      4.9      3.7  ...      5.0      5.4      6.3
#
# Hour              18       19       20       21       22      23        전체
# 요일
# 금요일           4248.0   4186.0   4115.0   3320.0   2280.0   304.0   47408.0
# 금요일 중 %          9.0      8.8      8.7      7.0      4.8     0.6     100.0
# 금요일Hour 중 %     15.5     14.6     14.9     15.8     17.2    17.8      16.3
# 금요일전체 %          1.5      1.4      1.4      1.1      0.8     0.1      16.3
# 목요일           4875.0   5102.0   4870.0   4083.0   2641.0   295.0   50716.0
# 목요일 중 %          9.6     10.1      9.6      8.1      5.2     0.6     100.0
# 목요일Hour 중 %     17.7     17.8     17.7     19.4     20.0    17.3      17.4
# 목요일전체 %          1.7      1.8      1.7      1.4      0.9     0.1      17.4
# 수요일           5318.0   5415.0   5068.0   4192.0   2553.0   341.0   52992.0
# 수요일 중 %         10.0     10.2      9.6      7.9      4.8     0.6     100.0
# 수요일Hour 중 %     19.3     18.9     18.4     19.9     19.3    20.0      18.2
# 수요일전체 %          1.8      1.9      1.7      1.4      0.9     0.1      18.2
# 월요일           5538.0   5972.0   5507.0   4378.0   2722.0   345.0   55674.0
# 월요일 중 %          9.9     10.7      9.9      7.9      4.9     0.6     100.0
# 월요일Hour 중 %     20.1     20.8     20.0     20.8     20.6    20.2      19.1
# 월요일전체 %          1.9      2.1      1.9      1.5      0.9     0.1      19.1
# 토요일           1912.0   2042.0   2329.0    494.0     22.0     1.0   28034.0
# 토요일 중 %          6.8      7.3      8.3      1.8      0.1     0.0     100.0
# 토요일Hour 중 %      7.0      7.1      8.5      2.3      0.2     0.1       9.6
# 토요일전체 %          0.7      0.7      0.8      0.2      0.0     0.0       9.6
# 화요일           5598.0   5927.0   5639.0   4605.0   3018.0   420.0   56460.0
# 화요일 중 %          9.9     10.5     10.0      8.2      5.3     0.7     100.0
# 화요일Hour 중 %     20.4     20.7     20.5     21.9     22.8    24.6      19.4
# 화요일전체 %          1.9      2.0      1.9      1.6      1.0     0.1      19.4
# 전체           27489.0  28644.0  27528.0  21072.0  13236.0  1706.0  291284.0
# 전체 중 %           9.4      9.8      9.5      7.2      4.5     0.6     100.0
# 전체Hour 중 %     100.0    100.0    100.0    100.0    100.0   100.0     100.0
# 전체전체 %           9.4      9.8      9.5      7.2      4.5     0.6     100.0
#
# [28 rows x 21 columns]

# %% [markdown]
# ### page 31 시각화

# %%
df = pd.read_csv('./data/2020_통합_v2.3_my idea.csv',encoding='cp949')

# %%
temp_df = pd.DataFrame(df.groupby('요일')['No'].count()).rename(columns={'No':'빈도'})
temp_df['퍼센트'] = np.round(temp_df['빈도']/temp_df['빈도'].sum()*100,1)
temp_df['누적퍼센트'] = np.cumsum(temp_df['퍼센트'])
temp_df
# Out:
#         빈도   퍼센트  누적퍼센트
# 요일
# 금요일  47408  16.3   16.3
# 목요일  50716  17.4   33.7
# 수요일  52992  18.2   51.9
# 월요일  55674  19.1   71.0
# 토요일  28034   9.6   80.6
# 화요일  56460  19.4  100.0

# %% [markdown]
# ### page 33 시각화

# %%
df = pd.read_csv('./data/2020_통합_v2.3_my idea.csv',encoding='cp949')

# %%
temp_df = pd.DataFrame(df.groupby(['요일','Area'])['No'].count()).unstack()

# %%
temp_df.loc['전체'] = temp_df.iloc[0:7].sum().to_list()

# %%
temp_df['전체'] = [temp_df.iloc[i].sum() for i in range(0,7)]

# %%
for i in temp_df.index.values:
    temp_df.loc[str(i)+'%'] = np.round(temp_df.loc[i]/temp_df.loc['전체']*100,1)

# %%
ls = []

for ind, i in enumerate(temp_df.index[:7]):
    ls.append(i)
    ls.append(temp_df.index[ind+7])

# %%
temp_df.reindex(index=ls)
# Out:
#            No                                                                \
# Area        A        B        C        D        E        F        G       T
# 요일
# 금요일    7371.0   5893.0   9983.0   5381.0   2802.0   7985.0   7051.0   942.0
# 금요일%     15.9     16.4     15.8     16.2     15.4     17.9     15.9    16.7
# 목요일    7903.0   6246.0  10924.0   5983.0   3300.0   7811.0   7468.0  1081.0
# 목요일%     17.0     17.4     17.3     18.1     18.1     17.5     16.9    19.2
# 수요일    8245.0   6670.0  11249.0   6483.0   3278.0   7947.0   8260.0   860.0
# 수요일%     17.8     18.6     17.8     19.6     18.0     17.8     18.7    15.3
# 월요일    9089.0   7062.0  12192.0   6646.0   3451.0   7994.0   8031.0  1209.0
# 월요일%     19.6     19.7     19.3     20.1     19.0     17.9     18.1    21.5
# 토요일    5038.0   2952.0   6867.0   1976.0   1832.0   4737.0   4225.0   407.0
# 토요일%     10.8      8.2     10.9      6.0     10.1     10.6      9.5     7.2
# 화요일    8800.0   7112.0  11827.0   6669.0   3534.0   8142.0   9248.0  1128.0
# 화요일%     18.9     19.8     18.8     20.1     19.4     18.2     20.9    20.0
# 전체    46446.0  35935.0  63042.0  33138.0  18197.0  44616.0  44283.0  5627.0
# 전체%     100.0    100.0    100.0    100.0    100.0    100.0    100.0   100.0
#
#             전체
# Area
# 요일
# 금요일    47408.0
# 금요일%      16.3
# 목요일    50716.0
# 목요일%      17.4
# 수요일    52992.0
# 수요일%      18.2
# 월요일    55674.0
# 월요일%      19.1
# 토요일    28034.0
# 토요일%       9.6
# 화요일    56460.0
# 화요일%      19.4
# 전체    291284.0
# 전체%      100.0

# %% [markdown]
# ### page 35 시각화

# %%
df = pd.read_csv('./data/2020_통합_v2.3_my idea.csv',encoding='cp949')

# %%
temp_df = df.groupby(['Age2','Area'])['No'].count().unstack()

# %%
import matplotlib.pyplot as plt

temp_df.boxplot(grid=False)
plt.axhline((temp_df.quantile(0.25).sum()/8),color='r',linestyle='--',linewidth=1)
plt.axhline((temp_df.quantile(0.5).sum()/8),color='r',linestyle='--',linewidth=1)
plt.axhline((temp_df.quantile(0.75).sum()/8),color='r',linestyle='--',linewidth=1)

# %% [markdown]
# ### page 37 시각화

# %%
df = pd.read_csv('./data/2020_통합_v2.3_my idea.csv',encoding='cp949')

# %%
temp_df = df.groupby(['Area','Age2'])['No'].count().unstack()

# %%
from collections import defaultdict

dict_temp = defaultdict(int)

for i in temp_df.columns:
    dict_temp[i//10] += temp_df[i]

# %%
temp_df = pd.DataFrame(dict_temp)
temp_df.columns = (temp_df.columns*10).to_list()

# %%
temp_df.loc['전체'] = temp_df.iloc[:8].sum().to_list()
temp_df['전체'] = [temp_df.iloc[i].sum() for i in range(0,9)]

# %%
import numpy

for i in temp_df.index.values:
    temp_df.loc[str(i)+' Area 중 %'] = np.round(temp_df.loc[i]/temp_df.loc[i]['전체']*100,1)
    
for i in temp_df.index[:9].values:
    temp_df.loc[str(i)+' Age2Range 중 %'] = np.round(temp_df.loc[i]/temp_df.loc['전체']*100,1)
    
for i in temp_df.index[:9].values:
    temp_df.loc[str(i)+' 전체 %'] = np.round(temp_df.loc[i]/temp_df.loc['전체']['전체']*100,1)

# %%
ls = []

for ind, i in enumerate(temp_df.index[:9]):
    ls.append(i)
    ls.append(temp_df.index[ind+9])
    ls.append(temp_df.index[ind+18])
    ls.append(temp_df.index[ind+27])

# %%
temp_df.reindex(index=ls).rename(columns={0:9.0})
# Out:
#                     9.0  10.0     20.0     30.0     40.0     50.0     60.0  \
# Area
# A                   NaN   NaN  10854.0  16716.0   6556.0   4137.0   3094.0
# A Area 중 %          NaN   NaN     26.2     40.4     15.9     10.0      7.5
# A Age2Range 중 %     NaN   NaN     14.2     22.1     15.3     15.8     16.5
# A 전체 %              NaN   NaN      4.5      7.0      2.7      1.7      1.3
# B                   NaN   NaN  11732.0   9322.0   6762.0   2561.0   1563.0
# B Area 중 %          NaN   NaN     36.7     29.2     21.2      8.0      4.9
# B Age2Range 중 %     NaN   NaN     15.3     12.3     15.8      9.8      8.3
# B 전체 %              NaN   NaN      4.9      3.9      2.8      1.1      0.7
# C                  11.0   NaN  16792.0  10283.0   5877.0   9007.0   8385.0
# C Area 중 %          0.0   NaN     33.3     20.4     11.7     17.9     16.7
# C Age2Range 중 %   100.0   NaN     21.9     13.6     13.7     34.4     44.7
# C 전체 %              0.0   NaN      7.0      4.3      2.4      3.8      3.5
# D                   NaN   NaN   6868.0  13220.0   6135.0      NaN      NaN
# D Area 중 %          NaN   NaN     26.2     50.4     23.4      NaN      NaN
# D Age2Range 중 %     NaN   NaN      9.0     17.5     14.3      NaN      NaN
# D 전체 %              NaN   NaN      2.9      5.5      2.6      NaN      NaN
# E                   NaN   NaN   6346.0   3356.0   2242.0   2551.0   1588.0
# E Area 중 %          NaN   NaN     39.5     20.9     13.9     15.9      9.9
# E Age2Range 중 %     NaN   NaN      8.3      4.4      5.2      9.7      8.5
# E 전체 %              NaN   NaN      2.6      1.4      0.9      1.1      0.7
# F                   NaN   NaN  11275.0  11744.0   6983.0   3906.0   2660.0
# F Area 중 %          NaN   NaN     30.8     32.1     19.1     10.7      7.3
# F Age2Range 중 %     NaN   NaN     14.7     15.5     16.3     14.9     14.2
# F 전체 %              NaN   NaN      4.7      4.9      2.9      1.6      1.1
# G                   NaN   NaN  11568.0  10436.0   7415.0   3236.0   1463.0
# G Area 중 %          NaN   NaN     33.9     30.6     21.7      9.5      4.3
# G Age2Range 중 %     NaN   NaN     15.1     13.8     17.3     12.4      7.8
# G 전체 %              NaN   NaN      4.8      4.3      3.1      1.3      0.6
# T                   NaN   NaN   1158.0    638.0    918.0    776.0      NaN
# T Area 중 %          NaN   NaN     33.2     18.3     26.3     22.2      NaN
# T Age2Range 중 %     NaN   NaN      1.5      0.8      2.1      3.0      NaN
# T 전체 %              NaN   NaN      0.5      0.3      0.4      0.3      NaN
# 전체                 11.0   0.0  76593.0  75715.0  42888.0  26174.0  18753.0
# 전체 Area 중 %         0.0   0.0     31.9     31.5     17.9     10.9      7.8
# 전체 Age2Range 중 %  100.0   NaN    100.0    100.0    100.0    100.0    100.0
# 전체 전체 %             0.0   0.0     31.9     31.5     17.9     10.9      7.8
#
#                   70.0  80.0        전체
# Area
# A                  NaN   NaN   41357.0
# A Area 중 %         NaN   NaN     100.0
# A Age2Range 중 %    NaN   NaN      17.2
# A 전체 %             NaN   NaN      17.2
# B                  NaN   NaN   31940.0
# B Area 중 %         NaN   NaN     100.0
# B Age2Range 중 %    NaN   NaN      13.3
# B 전체 %             NaN   NaN      13.3
# C                  NaN   NaN   50355.0
# C Area 중 %         NaN   NaN     100.0
# C Age2Range 중 %    NaN   NaN      21.0
# C 전체 %             NaN   NaN      21.0
# D                  NaN   NaN   26223.0
# D Area 중 %         NaN   NaN     100.0
# D Age2Range 중 %    NaN   NaN      10.9
# D 전체 %             NaN   NaN      10.9
# E                  NaN   NaN   16083.0
# E Area 중 %         NaN   NaN     100.0
# E Age2Range 중 %    NaN   NaN       6.7
# E 전체 %             NaN   NaN       6.7
# F                  NaN   NaN   36568.0
# F Area 중 %         NaN   NaN     100.0
# F Age2Range 중 %    NaN   NaN      15.2
# F 전체 %             NaN   NaN      15.2
# G                  NaN   NaN   34118.0
# G Area 중 %         NaN   NaN     100.0
# G Age2Range 중 %    NaN   NaN      14.2
# G 전체 %             NaN   NaN      14.2
# T                  NaN   NaN    3490.0
# T Area 중 %         NaN   NaN     100.0
# T Age2Range 중 %    NaN   NaN       1.5
# T 전체 %             NaN   NaN       1.5
# 전체                 0.0   0.0  240134.0
# 전체 Area 중 %        0.0   0.0     100.0
# 전체 Age2Range 중 %   NaN   NaN     100.0
# 전체 전체 %            0.0   0.0     100.0

# %% [markdown]
# ### page 41 시각화

# %%
df = pd.read_csv('./data/2020_통합_v2.3_my idea.csv',encoding='cp949')

# %%
temp_df = df.groupby(['Hour','Gender2'])['No'].count().unstack()

# %%
temp_df.loc['전체'] = temp_df.iloc[:20].sum().to_list()

# %%
temp_df['전체'] = [temp_df.iloc[i].sum() for i in range(0,21)]

# %%
for i in temp_df.index.values:
    temp_df.loc[str(i)+'%'] = np.round(temp_df.loc[i]/temp_df.loc['전체']*100,1)

# %%
ls = []

for ind, i in enumerate(temp_df.index[:21]):
    ls.append(i)
    ls.append(temp_df.index[ind+21])

# %%
temp_df.reindex(index=ls)
# Out:
# Gender2        남자        여자        전체
# Hour
# 0            15.0      19.0      34.0
# 0%            0.0       0.0       0.0
# 5          1126.0     498.0    1624.0
# 5%            0.7       0.4       0.6
# 6          7156.0    3688.0   10844.0
# 6%            4.5       2.8       3.7
# 7          8180.0    4778.0   12958.0
# 7%            5.1       3.6       4.4
# 8          6674.0    5952.0   12626.0
# 8%            4.2       4.5       4.3
# 9          5632.0    8933.0   14565.0
# 9%            3.5       6.8       5.0
# 10         6345.0    9414.0   15759.0
# 10%           4.0       7.2       5.4
# 11         7942.0    8337.0   16279.0
# 11%           5.0       6.4       5.6
# 12         8398.0    5945.0   14343.0
# 12%           5.2       4.5       4.9
# 13         6038.0    4798.0   10836.0
# 13%           3.8       3.7       3.7
# 14         7203.0    5684.0   12887.0
# 14%           4.5       4.3       4.4
# 15         8748.0    5935.0   14683.0
# 15%           5.5       4.5       5.0
# 16         9160.0    6520.0   15680.0
# 16%           5.7       5.0       5.4
# 17        10555.0    7936.0   18491.0
# 17%           6.6       6.1       6.3
# 18        14905.0   12584.0   27489.0
# 18%           9.3       9.6       9.4
# 19        14944.0   13700.0   28644.0
# 19%           9.3      10.5       9.8
# 20        14594.0   12934.0   27528.0
# 20%           9.1       9.9       9.5
# 21        12721.0    8351.0   21072.0
# 21%           7.9       6.4       7.2
# 22         8677.0    4559.0   13236.0
# 22%           5.4       3.5       4.5
# 23         1173.0     533.0    1706.0
# 23%           0.7       0.4       0.6
# 전체       160186.0  131098.0  291284.0
# 전체%         100.0     100.0     100.0

# %% [markdown]
# ### page 44 시각화

# %%
df = pd.read_csv('./data/2020_통합_v2.3_my idea.csv',encoding='cp949')

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')

temp_df = df.groupby(['Age2','Gender2'])['No'].count().unstack()
temp_df.boxplot()
plt.axhline((temp_df.quantile(0.5).sum()/2),color='r',linestyle='--',linewidth=1)

# %% [markdown]
# ### page 46 시각화

# %%
df = pd.read_csv('./data/2020_통합_v2.3_my idea.csv',encoding='cp949')

# %%
temp_df = df.groupby(['Gender2','Area'])['No'].count().unstack()

# %%
temp_df.loc['전체'] = temp_df.iloc[:2].sum().to_list()
temp_df['전체'] = [temp_df.iloc[i].sum() for i in range(0,3)]

# %%
import numpy

for i in temp_df.index.values:
    temp_df.loc[str(i)+'Gender2 중 %'] = np.round(temp_df.loc[i]/temp_df.loc[i]['전체']*100,1)
    
for i in temp_df.index[:3].values:
    temp_df.loc[str(i)+'Area 중 %'] = np.round(temp_df.loc[i]/temp_df.loc['전체']*100,1)
    
for i in temp_df.index[:3].values:
    temp_df.loc[str(i)+'전체 %'] = np.round(temp_df.loc[i]/temp_df.loc['전체']['전체']*100,1)

# %%
ls = []

for ind, i in enumerate(temp_df.index[:3]):
    ls.append(i)
    ls.append(temp_df.index[ind+3])
    ls.append(temp_df.index[ind+6])
    ls.append(temp_df.index[ind+9])

# %%
temp_df.reindex(index=ls)
# Out:
# Area                 A        B        C        D        E        F        G  \
# Gender2
# 남자             31486.0     28.0  34682.0  23747.0  10900.0  29828.0  29500.0
# 남자Gender2 중 %     19.7      0.0     21.7     14.8      6.8     18.6     18.4
# 남자Area 중 %        67.8      0.1     55.0     71.7     59.9     66.9     66.6
# 남자전체 %            10.8      0.0     11.9      8.2      3.7     10.2     10.1
# 여자             14960.0  35907.0  28360.0   9391.0   7297.0  14788.0  14783.0
# 여자Gender2 중 %     11.4     27.4     21.6      7.2      5.6     11.3     11.3
# 여자Area 중 %        32.2     99.9     45.0     28.3     40.1     33.1     33.4
# 여자전체 %             5.1     12.3      9.7      3.2      2.5      5.1      5.1
# 전체             46446.0  35935.0  63042.0  33138.0  18197.0  44616.0  44283.0
# 전체Gender2 중 %     15.9     12.3     21.6     11.4      6.2     15.3     15.2
# 전체Area 중 %       100.0    100.0    100.0    100.0    100.0    100.0    100.0
# 전체전체 %            15.9     12.3     21.6     11.4      6.2     15.3     15.2
#
# Area                T        전체
# Gender2
# 남자               15.0  160186.0
# 남자Gender2 중 %     0.0     100.0
# 남자Area 중 %        0.3      55.0
# 남자전체 %            0.0      55.0
# 여자             5612.0  131098.0
# 여자Gender2 중 %     4.3     100.0
# 여자Area 중 %       99.7      45.0
# 여자전체 %            1.9      45.0
# 전체             5627.0  291284.0
# 전체Gender2 중 %     1.9     100.0
# 전체Area 중 %      100.0     100.0
# 전체전체 %            1.9     100.0

# %% [markdown]
# ### page 48 시각화

# %%
df = pd.read_csv('./data/2020_통합_v2.3_my idea.csv',encoding='cp949')
df = df[['Date','Area']]

# %%
weather =  pd.read_csv('./data/2020_seoul_weather_v0.3.csv',encoding='cp949').rename(columns={'날짜':'Date'})

# %%
weather = weather[['Date','08시기준기온']]

# %%
temp_df = pd.merge(df,weather,how='inner',on='Date')
temp_df = temp_df[['Area','08시기준기온']]

# %%
import seaborn as sns

sns.heatmap(temp_df.groupby(['Area','08시기준기온'])['Area'].count().unstack())
# Out:
# <AxesSubplot:xlabel='08시기준기온', ylabel='Area'>
